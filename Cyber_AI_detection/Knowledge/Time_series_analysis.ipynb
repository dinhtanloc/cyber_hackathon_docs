# %% [markdown]
# A time series is a series of values obtained at successive times. For example, the price of the stock market sampled every minute froms a time series.
#
# In cyber security, time series analysis can be very handy for predicting a cyber attack, such as an insider employee exfiltrating data or a group of hackers colluding in preparation for their next hit.

# %%
# !pip install statsmodels scipy
# Out:
# Requirement already satisfied: statsmodels in d:\cyber_hackathon_docs\.conda\lib\site-packages (0.14.1)
# Requirement already satisfied: scipy in d:\cyber_hackathon_docs\.conda\lib\site-packages (1.10.1)
# Requirement already satisfied: numpy<2,>=1.18 in d:\cyber_hackathon_docs\.conda\lib\site-packages (from statsmodels) (1.24.4)
# Requirement already satisfied: pandas!=2.1.0,>=1.0 in d:\cyber_hackathon_docs\.conda\lib\site-packages (from statsmodels) (2.0.3)
# Requirement already satisfied: patsy>=0.5.4 in d:\cyber_hackathon_docs\.conda\lib\site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in d:\cyber_hackathon_docs\.conda\lib\site-packages (from statsmodels) (24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\cyber_hackathon_docs\.conda\lib\site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in d:\cyber_hackathon_docs\.conda\lib\site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in d:\cyber_hackathon_docs\.conda\lib\site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2024.1)
# Requirement already satisfied: six in d:\cyber_hackathon_docs\.conda\lib\site-packages (from patsy>=0.5.4->statsmodels) (1.16.0)

# %%
# Begin by generating a time series
from random import random
time_series = [2*x+random() for x in range(1,100)]

# %%
# plot our data
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(time_series)
plt.show()

# %%
# Autoregression (AR):
from statsmodels.tsa.ar_model import AutoReg
model = AutoReg(time_series,lags=1)
model_fit = model.fit()
y= model_fit.predict(len(time_series), len(time_series))
print(y)
# Out:
# [200.80116091]

# %%
from statsmodels.tsa.arima.model import ARIMA

# Assuming time_series is your time series data
model = ARIMA(time_series, order=(0, 0, 1))  # ARIMA(p, d, q) with p=0, d=0, and q=1 for MA(1)
model_fit = model.fit()

# Predicting the next value
y = model_fit.predict(len(time_series), len(time_series))

print(y)
# Out:
# [153.66722951]

# %%
# Simple exponential smoothing (SES)
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
model = SimpleExpSmoothing(time_series)
model_fit = model.fit()
y= model_fit.predict(len(time_series),len(time_series))
print(y)
# Out:
# [198.78594321]
